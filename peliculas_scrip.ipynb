# %% [markdown]
# Scrip que carga el archivo 'peliculas.csv' y genera una grafica para representar

# %%
datos = read.csv("peliculas.csv")

# %%
#variables:
x = datos$critic_score[1:20] #puntuacion de la critica

#grafica:
barplot(x, xlab = "Peliculas", ylab = "Puntuaciones de la critica")
# Out:
# plot without title

# %%
?barplot
